# %% [markdown]
# <a href="https://colab.research.google.com/github/metelitt/Beauty/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Yolo_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.9/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ad03ba4-b873-48e1-9aef-ce727fdb023c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ad03ba4-b873-48e1-9aef-ce727fdb023c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install unrar
# !unrar x vendor_0.rar
# Out:
# ...
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from vendor_0.rar
#
# Creating    vendor_0                                                  OK
#   OK
# Creating    vendor_0/test                                             OK
# Creating    vendor_0/test/images                                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data = '/content/vendor_0/data.yaml' epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import numpy as np
import cv2
from PIL import Image
from io import BytesIO
from google.colab.patches import cv2_imshow
from ultralytics import YOLO

# Загрузка модели YOLOv8 (замените на ваш реальный путь)
model = YOLO('/')

# Загрузка изображения по пути (замените на ваш реальный путь)
image_path = '/content/3029medium.jpeg'
image = cv2.imread(image_path)
results = model(image)
"""
Написать код для обработки результатов модели и отображения на изображении.
"""
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
"""Реализовать функционал трекера (например, ByteTracker). Если не знаете языков программирования, то можно обосновать свой алгоритм математически (сам алгоритм и обоснование отправить мне в лс)"""
